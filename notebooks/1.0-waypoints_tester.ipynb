# %%
import os
import random
import yaml
import numpy as np

# %%
filename = 'waypoints.yaml'

n_points = 5
min_x = -1
min_y = -1
max_x = 1
max_y = 1
min_th = 0
max_th = 2*np.pi

res = 100

data = {}

# %% [markdown]
# # Writing points in wayponits.yaml

# %%
for idx in range(n_points):
    x_ = random.randint(min_x*res, max_x*res)/res
    y_ = random.randint(min_y*res, max_y*res)/res
    thetha_ = random.randint(int(min_th*res), int(max_th*res))/res

    print(f'[x: {x_}, y: {y_}, th: {thetha_}]')

    data[idx] = [x_, y_, thetha_]
# Out:
# [x: -0.93, y: 0.83, th: 3.72]
# [x: 1.0, y: 0.0, th: 5.94]
# [x: -0.65, y: -0.98, th: 4.48]
# [x: -0.47, y: 0.93, th: 3.38]
# [x: 0.8, y: 0.41, th: 4.06]

# %%
with open(filename, 'w') as f:
    yaml.dump(data, f)

print(f"Waypoints file has been successfully written.")
# Out:
# Waypoints file has been successfully written.

# %% [markdown]
# # Reading waypoints.yaml

# %%
with open(filename, 'r') as f:
    loaded_data = yaml.safe_load(f)

print(f"Data read from {filename}")
print(loaded_data)
# Out:
# Data read from waypoints.yaml
# {0: [-0.93, 0.83, 3.72], 1: [1.0, 0.0, 5.94], 2: [-0.65, -0.98, 4.48], 3: [-0.47, 0.93, 3.38], 4: [0.8, 0.41, 4.06]}

# %%
loaded_data[0]
# Out:
# [-0.93, 0.83, 3.72]
